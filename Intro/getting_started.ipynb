# %% [markdown]
# # Welcome to vCDAT
# This is your personal JupyterLab vCDAT interface.
#
# Just press **shift-enter** to follow this getting started guide.

# %% [markdown]
# ## Resources
# A small introduction video to JupyterLab.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ctOM-Gza04Y')

# %% [markdown]
# ## Using Your Own Data
#
# If you didn't do so yet, follow instructions the [README file](../README.md) to link to the pre-downloaded data.
#
# ```bash
# cd $HOME
# ln -s /global/cscratch1/sd/cmip6 cmip6_data
# ```
#
# Now in the jupyter interface you should see a directory called `cmip6_data` simply click on it and you are where you want to be. Further browse to the `CMIP6/CMIP/NCAR/CESM2/historical/r1i1p1f1/Amon/tas/gn/v20190308` directory and double click on the `tas_Amon_CESM2_historical_r1i1p1f1_gn_185001-201412.nc` file

# %% [markdown]
# ***WARNING***
#
# The JupyterLab file browser allows you to double click on a file to open it. Unfortunately this means loading the whole file into the browser. For netCDF files this is not practical (these files can be several Gb), so we kill the transfer to prevent the file from loading. Unfortunately this brings up the following error message. You can ***safely ignore*** the error message and move on. The creators of Jupyterlab are aware of the problem and are implementing a solution for big files.
#
# ![File Loading Message In VCDAT](https://cdat.llnl.gov/cdat/vcdat/images/file_load_error_vcdat.png)

# %% [markdown]
# ## Software
#
# VCDAT Jupyter-lab comes with the following core tools:
#
# * python >3
# * cdat_info
# * cdms2
# * cdutil
# * genutil
# * vcs
# * dv3d
# * libcdms >=3.1.2
# * vtk-cdat >8.1
# * requests
# * numpy
# * ghostscript
# * nodejs
# * jupyterlab
# * pip
# * nb_conda
# * nb_conda_kernels
# * plumbum
# * jupyterhub

# %% [markdown]
# ## Next Steps
#
# For more details on the user interface, see the [VCDAT User Interface](https://github.com/CDAT/jupyter-vcdat/wiki/User-Interface) wiki page.
#
#
# CDAT (and vCDAT) can open any OPeNDAP file so if you wanted to get the latest CMIP6 data or other climate data you could use the Earth System Grid Federation (ESGF) data warehouse interface to access the OPeNDAP URL for that data. [This page](https://www.earthsystemcog.org/projects/cog/doc/opendap) provides details on browsing and downloading data from ESGF using OPeNDAP. In these tutorials we will use local data only.
#
# At this point you probably want to [Load Variables](https://github.com/CDAT/jupyter-vcdat/wiki/Load-Variables) and plot them (see the [Plot Variables](https://github.com/CDAT/jupyter-vcdat/wiki/Plot-Variables) page).
